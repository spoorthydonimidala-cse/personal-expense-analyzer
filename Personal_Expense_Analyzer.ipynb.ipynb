# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("expenses.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("expenses.csv")
#       2 df.head()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
df = pd.read_csv("expenses.csv")
df.head()
# Out:
#          Date       Category  Amount      Description
# 0  2026-01-02           Food     250            Lunch
# 1  2026-01-03         Travel     120         Bus fare
# 2  2026-01-04       Shopping    1500          Clothes
# 3  2026-01-05          Bills     800  Mobile recharge
# 4  2026-01-06  Entertainment     300            Movie

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         10 non-null     str
#  1   Category     10 non-null     str
#  2   Amount       10 non-null     int64
#  3   Description  10 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 452.0 bytes

# %%
df["Amount"].sum()
# Out:
# np.int64(7450)

# %%
df.groupby("Category")["Amount"].sum()
# Out:
# Category
# Bills            2300
# Entertainment     300
# Food              830
# Shopping         3700
# Travel            320
# Name: Amount, dtype: int64

# %%
df.groupby("Category")["Amount"].sum().plot(kind="bar")

plt.title("Category-wise Spending")
plt.xlabel("Category")
plt.ylabel("Total Amount")

plt.show()

# %%
df.groupby("Category")["Amount"].sum().plot(kind="pie", autopct="%1.1f%%")

plt.title("Expense Distribution by Category")
plt.ylabel("")

plt.show()

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Month"] = df["Date"].dt.month_name()

df.head()
# Out:
#         Date       Category  Amount      Description    Month
# 0 2026-01-02           Food     250            Lunch  January
# 1 2026-01-03         Travel     120         Bus fare  January
# 2 2026-01-04       Shopping    1500          Clothes  January
# 3 2026-01-05          Bills     800  Mobile recharge  January
# 4 2026-01-06  Entertainment     300            Movie  January

# %%
df.groupby("Month")["Amount"].sum()
# Out:
# Month
# January    7450
# Name: Amount, dtype: int64

# %%
df.groupby("Month")["Amount"].sum().plot(kind="bar")

plt.title("Monthly Spending")
plt.xlabel("Month")
plt.ylabel("Total Amount")

plt.show()

# %%
df.groupby("Category")["Amount"].sum().idxmax()
# Out:
# 'Shopping'

# %% [markdown]
# ## Conclusion
#
# This project analyzes personal expenses using Python.
#
# Key findings:
# 1. Calculated total amount spent.
# 2. Identified category-wise spending patterns.
# 3. Visualized expenses using bar charts and pie charts.
# 4. Determined the category with the highest spending.
